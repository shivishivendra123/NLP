# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/shivendragupta/Desktop/NLP/IMDB Dataset 2.csv')

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %% [markdown]
# # Lower Casing

# %%
df['review'][6].lower()
# Out:
# "i sure would like to see a resurrection of a up dated seahunt series with the tech they have today it would bring back the kid excitement in me.i grew up on black and white tv and seahunt with gunsmoke were my hero's every week.you have my vote for a comeback of a new sea hunt.we need a change of pace in tv and this would work for a world of under water adventure.oh by the way thank you for an outlet like this to view many viewpoints about tv and the many movies.so any ole way i believe i've got what i wanna say.would be nice to read some more plus points about sea hunt.if my rhymes would be 10 lines would you let me submit,or leave me out to be in doubt and have me to quit,if this is so then i must go so lets do it."

# %%
df['review'] = df['review'].str.lower()

# %%
df.head()
# Out:
#                                               review sentiment
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production. <br /><br />the...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically there's a family where a little boy ...  negative
# 4  petter mattei's "love in the time of money" is...  positive

# %% [markdown]
# # Removing HTML tags

# %%
import re

# %%
def removeHtmlTags(text):
    pattern = re.compile('<.*?>')
    return pattern.sub(r'',text)

# %%
df['review'] = df['review'].apply(removeHtmlTags)

# %%
df.head()
# Out:
#                                               review sentiment
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production. the filming tec...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically there's a family where a little boy ...  negative
# 4  petter mattei's "love in the time of money" is...  positive

# %% [markdown]
# # Remove URLS

# %%
def remove_url(text):
    pattern = re.compile(r'https:?//\S+|www\.\S+') 
    return pattern.sub(r'',text)

# %%
text1 = "check out my link https://www.google.com"

# %%
remove_url(text1)
# Out:
# 'check out my link '

# %% [markdown]
# # Remove punctuations

# %%
import string

# %%
exclude = string.punctuation

# %%
def removePunc(text):
    for i in exclude:
        text = text.replace(i,'')
    return text

# %%
df['review'] = df['review'].apply(removePunc)

# %%
df.head()
# Out:
#                                               review sentiment
# 0  one of the other reviewers has mentioned that ...  positive
# 1  a wonderful little production the filming tech...  positive
# 2  i thought this was a wonderful way to spend ti...  positive
# 3  basically theres a family where a little boy j...  negative
# 4  petter matteis love in the time of money is a ...  positive

# %%
def removePuncFaster(text):
    return text.translate(str.maketrans('','',exclude))

# %%
df['review'] = df['review'].apply(removePuncFaster)

# %% [markdown]
# # Chat Word Treatment

# %%
slangs = {
  "AFAIK": "As Far As I Know",
  "AFK": "Away From Keyboard",
  "ASAP": "As Soon As Possible",
  "ATK": "At The Keyboard",
  "ATM": "At The Moment",
  "A3": "Anytime, Anywhere, Anyplace",
  "BAK": "Back At Keyboard",
  "BBL": "Be Back Later",
  "BBS": "Be Back Soon",
  "BFN": "Bye For Now",
  "B4N": "Bye For Now",
  "BRB": "Be Right Back",
  "BRT": "Be Right There",
  "BTW": "By The Way",
  "B4": "Before",
  "CU": "See You",
  "CUL8R": "See You Later",
  "CYA": "See You",
  "FAQ": "Frequently Asked Questions",
  "FC": "Fingers Crossed",
  "FWIW": "For What It's Worth",
  "FYI": "For Your Information",
  "GAL": "Get A Life",
  "GG": "Good Game",
  "GN": "Good Night",
  "GMTA": "Great Minds Think Alike",
  "GR8": "Great!",
  "G9": "Genius",
  "IC": "I See",
  "ICQ": "I Seek You",
  "ILU": "I Love You",
  "IMHO": "In My Honest/Humble Opinion",
  "IMO": "In My Opinion",
  "IOW": "In Other Words",
  "IRL": "In Real Life",
  "KISS": "Keep It Simple, Stupid",
  "LDR": "Long Distance Relationship",
  "LMAO": "Laugh My A** Off",
  "LOL": "Laughing Out Loud",
  "LTNS": "Long Time No See",
  "L8R": "Later",
  "MTE": "My Thoughts Exactly",
  "M8": "Mate",
  "NRN": "No Reply Necessary",
  "OIC": "Oh I See",
  "PITA": "Pain In The A**",
  "PRT": "Party",
  "PRW": "Parents Are Watching",
  "QPSA?": "Que Pasa?",
  "ROFL": "Rolling On The Floor Laughing",
  "ROFLOL": "Rolling On The Floor Laughing Out Loud",
  "ROTFLMAO": "Rolling On The Floor Laughing My A** Off",
  "SK8": "Skate",
  "STATS": "Your sex and age",
  "ASL": "Age, Sex, Location",
  "THX": "Thank You",
  "TTFN": "Ta-Ta For Now!",
  "TTYL": "Talk To You Later",
  "U": "You",
  "U2": "You Too",
  "U4E": "Yours For Ever",
  "WB": "Welcome Back",
  "WTF": "What The F***",
  "WTG": "Way To Go!",
  "WUF": "Where Are You From?",
  "W8": "Wait...",
  "7K": "Sick:-D Laugher",
  "TFW": "That feeling when",
  "MFW": "My face when",
  "MRW": "My reaction when",
  "IFYP": "I feel your pain",
  "TNTL": "Trying not to laugh",
  "JK": "Just kidding",
  "IDC": "I dont care",
  "ILY": "I love you",
  "IMU": "I miss you",
  "ADIH": "Another day in hell",
  "ZZZ": "Sleeping, bored, tired",
  "WYWH": "Wish you were here",
  "TIME": "Tears in my eyes",
  "BAE": "Before anyone else",
  "FIMH": "Forever in my heart",
  "BSAAW": "Big smile and a wink",
  "BWL": "Bursting with laughter",
  "BFF": "Best friends forever",
  "CSL": "Cant stop laughing"
}

# %%
def ChatWordTreatement(text):
    for key,value in slangs.items():
        text = text.replace(key,value)
    return text

# %%
text = 'MTE very nice'

# %%
ChatWordTreatement(text)
# Out:
# 'My Thoughts Exactly very nice'

# %% [markdown]
# # Spelling correction

# %%
from textblob import TextBlob

# %%
text = "this line has sptlling mistakes"

# %%
txtblb = TextBlob(text)

# %%
txtblb.correct().string
# Out:
# 'this line has spelling mistakes'

# %% [markdown]
# # Removing stop words

# %% [markdown]
# # a are the of my

# %%
from nltk.corpus import stopwords
import nltk

# %%
sw = stopwords.words('english')

# %%
def removeStopWords(text):
    new_text = []
    for word in text.split():
        if word in sw:
            new_text.append('')
        else:
            new_text.append(word)
    return " ".join(new_text)

# %%
text1 = 'my name is shivendra gupta'

# %%
removeStopWords(text1)
# Out:
# ' name  shivendra gupta'

# %%
df['review'] = df['review'].apply(removeStopWords)

# %%
df.head()
# Out:
#                                               review sentiment
# 0  one    reviewers  mentioned   watching  1 oz e...  positive
# 1   wonderful little production  filming techniqu...  positive
# 2   thought    wonderful way  spend time    hot s...  positive
# 3  basically theres  family   little boy jake thi...  negative
# 4  petter matteis love   time  money   visually s...  positive

# %%
import emoji

# %%
print(emoji.demojize("As Far As I Know 🤔"))
# Out:
# As Far As I Know :thinking_face:

# %%
import re

def remove_emojis(text):
    emoji_pattern = re.compile("["
                                "\U0001F600-\U0001F64F"  # Emoticons
                                "\U0001F300-\U0001F5FF"  # Symbols & pictographs
                                "\U0001F680-\U0001F6FF"  # Transport & map symbols
                                "\U0001F1E0-\U0001F1FF"  # Flags (iOS)
                                "\U00002702-\U000027B0"  # Dingbats
                                "\U000024C2-\U0001F251"  # Enclosed characters
                                "]+", flags=re.UNICODE)
    
    return emoji_pattern.sub(r'', text)

text_with_emojis = "Hello 😂, I love Python 🐍! How are you? 😊"

# %%
remove_emojis(text_with_emojis)
# Out:
# 'Hello , I love Python ! How are you? '

# %% [markdown]
# # Tokenization

# %%
text = "I have a M.S degree in A.I!"

# %%
text.split()
# Out:
# ['I', 'have', 'a', 'M.S', 'degree', 'in', 'A.I!']

# %%
nltk.word_tokenize(text)
# Out:
# ['I', 'have', 'a', 'M.S', 'degree', 'in', 'A.I', '!']

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')
# Out:
#   Cell In[106], line 1
#     python -m spacy download en_core_web_sm
#               ^
# SyntaxError: invalid syntax

# %%
doc1 = nlp(text)

# %%
for token in doc1:
    print(token)

# %% [markdown]
# # Stemming

# %%
from nltk.stem.porter import PorterStemmer

# %%
ps = PorterStemmer()

# %%
def stem(text):
    return " ".join([ps.stem(word) for word in text.split()])

# %%
text = 'walking the walked walk'

# %%
stem(text)
# Out:
# 'walk the walk walk'

# %%
text1 = "probably the alltime"

# %%
stem(text1)
# Out:
# 'probabl the alltim'

# %%
from nltk.stem import WordNetLemmatizer

# %%
word_net_lemma = WordNetLemmatizer()

# %%
text = "He was running and eating at the same time.He has bad habit of swimming afte playing long hours in the sun."

# %%
for word in text:
    for i in exclude:
        word.replace(i,'')

# %%
for word in text.split():
    print(word_net_lemma.lemmatize(word,pos='v'))
# Out:
# He
# be
# run
# and
# eat
# at
# the
# same
# time.He
# have
# bad
# habit
# of
# swim
# afte
# play
# long
# hours
# in
# the
# sun.

# %% [markdown]
# # Bag of Word

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer()

# %%
bow = cv.fit_transform(df['review'])

# %%
cv.vocabulary_
# Out:
# {'one': 139493,
#  'reviewers': 163208,
#  'mentioned': 123484,
#  'watching': 212112,
#  'oz': 143239,
#  'episode': 64541,
#  'youll': 220085,
#  'hooked': 93682,
#  'right': 163980,
#  'exactly': 66499,
#  'happened': 87829,
#  'methe': 124089,
#  'first': 73580,
#  'thing': 195593,
#  'struck': 187144,
#  'brutality': 29026,
#  'unflinching': 205255,
#  'scenes': 169441,
#  'violence': 209793,
#  'set': 173770,
#  'word': 217165,
#  'go': 82283,
#  'trust': 202166,
#  'show': 176147,
#  'faint': 69036,
#  'hearted': 89458,
#  'timid': 198062,
#  'pulls': 155907,
#  'punches': 155990,
#  'regards': 160605,
#  'drugs': 58777,
#  'sex': 174036,
#  'hardcore': 88126,
#  'classic': 38397,
#  'use': 207262,
#  'wordit': 217184,
#  'called': 31237,
#  'nickname': 134175,
#  'given': 81823,
#  'oswald': 141361,
#  'maximum': 121508,
#  'security': 171641,
#  'state': 184726,
#  'penitentary': 146129,
#  'focuses': 74986,
#  'mainly': 118473,
#  'emerald': 62419,
#  'city': 38093,
#  'experimental': 67616,
#  'section': 171606,
#  'prison': 153800,
#  'cells': 34270,
#  'glass': 81949,
#  'fronts': 77723,
#  'face': 68624,
#  'inwards': 101315,
#  'privacy': 153858,
#  'high': 91353,
#  'agenda': 8031,
#  'em': 62259,
#  'home': 93262,
#  'manyaryans': 119746,
#  'muslims': 131380,
#  'gangstas': 79388,
#  'latinos': 110948,
#  'christians': 37299,
#  'italians': 102211,
#  'irish': 101440,
#  'moreso': 128208,
#  'scuffles': 171041,
#  'death': 49747,
#  'stares': 184417,
#  'dodgy': 56257,
#  'dealings': 49679,
#  'shady': 174392,
#  'agreements': 8307,
#  'never': 133690,
#  'far': 69852,
#  'awayi': 17317,
#  'would': 217980,
#  'say': 168784,
#  'main': 118452,
#  'appeal': 13585,
#  'due': 59125,
#  'fact': 68779,
#  'goes': 82565,
#  'shows': 176338,
#  'wouldnt': 218000,
#  'dare': 48725,
#  'forget': 75794,
#  'pretty': 153459,
#  'pictures': 148247,
#  'painted': 143631,
#  'mainstream': 118486,
#  'audiences': 16541,
#  'charm': 35683,
#  'romanceoz': 165428,
#  'doesnt': 56318,
#  'mess': 123836,
#  'around': 14699,
#  'ever': 65925,
#  'saw': 168719,
#  'nasty': 132434,
#  'surreal': 189884,
#  'couldnt': 44663,
#  'ready': 158980,
#  'watched': 212066,
#  'developed': 52584,
#  'taste': 192232,
#  'got': 83650,
#  'accustomed': 5535,
#  'levels': 112856,
#  'graphic': 84208,
#  'injustice': 99436,
#  'crooked': 46682,
#  'guards': 85484,
#  'wholl': 215013,
#  'sold': 180656,
#  'nickel': 134149,
#  'inmates': 99479,
#  'kill': 107539,
#  'order': 140801,
#  'get': 80899,
#  'away': 17278,
#  'well': 213322,
#  'mannered': 119499,
#  'middle': 124530,
#  'class': 38379,
#  'turned': 202692,
#  'bitches': 23882,
#  'lack': 109702,
#  'street': 186773,
#  'skills': 178381,
#  'experience': 67530,
#  'may': 121529,
#  'become': 20865,
#  'comfortable': 40879,
#  'uncomfortable': 204436,
#  'viewingthats': 209461,
#  'touch': 199889,
#  'darker': 48780,
#  'side': 176827,
#  'wonderful': 216850,
#  'little': 114613,
#  'production': 154250,
#  'filming': 72414,
#  'technique': 192727,
#  'unassuming': 204192,
#  'oldtimebbc': 139168,
#  'fashion': 70174,
#  'gives': 81844,
#  'comforting': 40887,
#  'sometimes': 181045,
#  'discomforting': 54866,
#  'sense': 172961,
#  'realism': 159057,
#  'entire': 64271,
#  'piece': 148324,
#  'actors': 6283,
#  'extremely': 68218,
#  'chosen': 37204,
#  'michael': 124334,
#  'sheen': 174965,
#  'polari': 150618,
#  'voices': 210320,
#  'pat': 145169,
#  'truly': 202123,
#  'see': 171699,
#  'seamless': 171193,
#  'editing': 60794,
#  'guided': 85660,
#  'references': 160412,
#  'williams': 215580,
#  'diary': 53124,
#  'entries': 64350,
#  'worth': 217909,
#  'terrificly': 193731,
#  'written': 218423,
#  'performed': 146760,
#  'masterful': 120838,
#  'great': 84454,
#  'masters': 120917,
#  'comedy': 40657,
#  'life': 113232,
#  'really': 159215,
#  'comes': 40845,
#  'things': 195681,
#  'fantasy': 69759,
#  'guard': 85463,
#  'rather': 158502,
#  'traditional': 200365,
#  'dream': 58216,
#  'techniques': 192731,
#  'remains': 161330,
#  'solid': 180730,
#  'disappears': 54546,
#  'plays': 149611,
#  'knowledge': 108581,
#  'senses': 173028,
#  'particularly': 144736,
#  'concerning': 42043,
#  'orton': 141199,
#  'halliwell': 87139,
#  'sets': 173813,
#  'flat': 74107,
#  'halliwells': 87140,
#  'murals': 130933,
#  'decorating': 50312,
#  'every': 66139,
#  'surface': 189688,
#  'terribly': 193708,
#  'done': 56811,
#  'thought': 196492,
#  'way': 212474,
#  'spend': 182689,
#  'time': 197485,
#  'hot': 94427,
#  'summer': 188833,
#  'weekend': 213041,
#  'sitting': 178018,
#  'air': 8575,
#  'conditioned': 42230,
#  'theater': 194426,
#  'lighthearted': 113590,
#  'plot': 149858,
#  'simplistic': 177479,
#  'dialogue': 52985,
#  'witty': 216473,
#  'characters': 35351,
#  'likable': 113672,
#  'even': 65807,
#  'bread': 27760,
#  'suspected': 190051,
#  'serial': 173466,
#  'killer': 107601,
#  'disappointed': 54563,
#  'realize': 159187,
#  'match': 120997,
#  'point': 150346,
#  'risk': 164358,
#  'addiction': 6697,
#  'proof': 154784,
#  'woody': 217073,
#  'allen': 9520,
#  'still': 185494,
#  'fully': 78050,
#  'control': 43415,
#  'style': 187683,
#  'many': 119742,
#  'us': 207185,
#  'grown': 85286,
#  'lovethis': 116528,
#  'id': 96407,
#  'laughed': 111074,
#  'woodys': 217077,
#  'comedies': 40632,
#  'years': 219402,
#  'decade': 50029,
#  'ive': 103057,
#  'impressed': 97763,
#  'scarlet': 169150,
#  'johanson': 104750,
#  'managed': 119053,
#  'tone': 199059,
#  'sexy': 174237,
#  'image': 97116,
#  'jumped': 105524,
#  'average': 17063,
#  'spirited': 182928,
#  'young': 220096,
#  'womanthis': 216752,
#  'crown': 46882,
#  'jewel': 104271,
#  'career': 32424,
#  'wittier': 216466,
#  'devil': 52699,
#  'wears': 212883,
#  'prada': 152429,
#  'interesting': 100471,
#  'superman': 189292,
#  'friends': 77391,
#  'basically': 19841,
#  'theres': 195328,
#  'family': 69374,
#  'boy': 27139,
#  'jake': 103408,
#  'thinks': 195879,
#  'zombie': 221075,
#  'closet': 39205,
#  'parents': 144382,
#  'fighting': 71914,
#  'timethis': 197982,
#  'movie': 129107,
#  'slower': 179266,
#  'soap': 180189,
#  'opera': 140395,
#  'suddenly': 188490,
#  'decides': 50195,
#  'rambo': 157974,
#  'zombieok': 221110,
#  'youre': 220179,
#  'going': 82640,
#  'make': 118567,
#  'film': 72077,
#  'must': 131406,
#  'decide': 50184,
#  'thriller': 196779,
#  'drama': 57960,
#  'watchable': 212008,
#  'divorcing': 55897,
#  'arguing': 14383,
#  'like': 113692,
#  'real': 159014,
#  'totally': 199826,
#  'ruins': 166506,
#  'expected': 67431,
#  'boogeyman': 26062,
#  'similar': 177347,
#  'instead': 99971,
#  'meaningless': 122310,
#  'spots3': 183496,
#  '10': 92,
#  'playing': 149569,
#  'descent': 51912,
#  'dialogs': 52971,
#  'shots': 176020,
#  'ignore': 96783,
#  'petter': 147450,
#  'matteis': 121263,
#  'love': 116277,
#  'money': 127281,
#  'visually': 210091,
#  'stunning': 187483,
#  'watch': 211996,
#  'mr': 130131,
#  'mattei': 121260,
#  'offers': 138317,
#  'vivid': 210185,
#  'portrait': 151516,
#  'human': 95301,
#  'relations': 161011,
#  'seems': 171850,
#  'telling': 193188,
#  'power': 152255,
#  'success': 188259,
#  'people': 146225,
#  'different': 53570,
#  'situations': 178054,
#  'encounter': 62838,
#  'variation': 208151,
#  'arthur': 14974,
#  'schnitzlers': 169863,
#  'play': 149467,
#  'theme': 194697,
#  'director': 54250,
#  'transfers': 200695,
#  'action': 5984,
#  'present': 153210,
#  'new': 133750,
#  'york': 219918,
#  'meet': 122733,
#  'connect': 42578,
#  'connected': 42579,
#  'another': 12274,
#  'next': 133939,
#  'person': 147067,
#  'know': 108521,
#  'previous': 153534,
#  'contact': 43045,
#  'stylishly': 187744,
#  'sophisticated': 181454,
#  'luxurious': 117297,
#  'look': 115633,
#  'taken': 191453,
#  'live': 114677,
#  'world': 217528,
#  'habitatthe': 86428,
#  'gets': 80939,
#  'souls': 181722,
#  'picture': 148189,
#  'stages': 184035,
#  'loneliness': 115403,
#  'inhabits': 99319,
#  'big': 23313,
#  'best': 22527,
#  'place': 149020,
#  'find': 73190,
#  'sincere': 177573,
#  'fulfillment': 77977,
#  'discerns': 54817,
#  'case': 33176,
#  'encounterthe': 62856,
#  'acting': 5822,
#  'good': 82930,
#  'direction': 54173,
#  'steve': 185332,
#  'buscemi': 30179,
#  'rosario': 165789,
#  'dawson': 49229,
#  'carol': 32821,
#  'kane': 106149,
#  'imperioli': 97564,
#  'adrian': 7046,
#  'grenier': 84772,
#  'rest': 162558,
#  'talented': 191564,
#  'cast': 33373,
#  'come': 40579,
#  'alivewe': 9377,
#  'wish': 216149,
#  'luck': 116863,
#  'await': 17201,
#  'anxiously': 12956,
#  'work': 217251,
#  'probably': 153941,
#  'alltime': 9829,
#  'favorite': 70614,
#  'story': 186111,
#  'selflessness': 172440,
#  'sacrifice': 167156,
#  'dedication': 50365,
#  'noble': 134793,
#  'cause': 33937,
#  'preachy': 152569,
#  'boring': 26536,
#  'old': 139059,
#  'despite': 52226,
#  'seen': 171868,
#  '15': 731,
#  'times': 197805,
#  'last': 110682,
#  '25': 2411,
#  'paul': 145455,
#  'lukas': 117013,
#  'performance': 146600,
#  'brings': 28371,
#  'tears': 192643,
#  'eyes': 68407,
#  'bette': 22733,
#  'davis': 49174,
#  'sympathetic': 190853,
#  'roles': 165188,
#  'delight': 50941,
#  'kids': 107384,
#  'grandma': 84113,
#  'says': 168883,
#  'dressedup': 58402,
#  'midgets': 124603,
#  'children': 36657,
#  'makes': 118626,
#  'fun': 78097,
#  'mothers': 128722,
#  'slow': 179244,
#  'awakening': 17217,
#  'whats': 214368,
#  'happening': 87880,
#  'roof': 165606,
#  'believable': 21704,
#  'startling': 184660,
#  'dozen': 57807,
#  'thumbs': 197147,
#  'theyd': 195475,
#  'sure': 189636,
#  'resurrection': 162754,
#  'dated': 48993,
#  'seahunt': 171163,
#  'series': 173487,
#  'tech': 192687,
#  'today': 198528,
#  'bring': 28363,
#  'back': 17901,
#  'kid': 107279,
#  'excitement': 66819,
#  'mei': 122903,
#  'grew': 84793,
#  'black': 24081,
#  'white': 214779,
#  'tv': 202846,
#  'gunsmoke': 85971,
#  'heros': 90881,
#  'weekyou': 213098,
#  'vote': 210516,
#  'comeback': 40589,
#  'sea': 171118,
#  'huntwe': 95728,
#  'need': 133084,
#  'change': 34959,
#  'pace': 143308,
#  'water': 212284,
#  'adventureoh': 7181,
#  'thank': 194102,
#  'outlet': 141939,
#  'view': 209321,
#  'viewpoints': 209484,
#  'moviesso': 129847,
#  'ole': 139181,
#  'believe': 21761,
#  'wanna': 211259,
#  'saywould': 168926,
#  'nice': 134037,
#  'read': 158916,
#  'plus': 150166,
#  'points': 150474,
#  'huntif': 95708,
#  'rhymes': 163540,
#  'lines': 114121,
#  'let': 112704,
#  'submitor': 187976,
#  'leave': 111817,
#  'doubt': 57456,
#  'quitif': 157257,
#  'lets': 112746,
#  'amazing': 10620,
#  'fresh': 77220,
#  'innovative': 99586,
#  'idea': 96416,
#  '70s': 3792,
#  'aired': 8605,
#  'brilliant': 28266,
#  'dropped': 58661,
#  '1990': 1787,
#  'funny': 78294,
#  'anymore': 12996,
#  'continued': 43249,
#  'decline': 50272,
#  'complete': 41620,
#  'waste': 211896,
#  'todayits': 198563,
#  'disgraceful': 55077,
#  'fallen': 69223,
#  'writing': 218371,
#  'painfully': 143581,
#  'bad': 18190,
#  'performances': 146673,
#  'almost': 9977,
#  'mildly': 124851,
#  'entertaining': 64085,
#  'respite': 162511,
#  'guesthosts': 85604,
#  'hard': 88107,
#  'creator': 45904,
#  'handselected': 87573,
#  'original': 140989,
#  'also': 10251,
#  'chose': 37202,
#  'band': 19049,
#  'hacks': 86495,
#  'followed': 75158,
#  'recognize': 159828,
#  'brilliance': 28253,
#  'fit': 73774,
#  'replace': 161908,
#  'mediocrity': 122634,
#  'felt': 71208,
#  'give': 81814,
#  'stars': 184518,
#  'respect': 162455,
#  'made': 117862,
#  'huge': 95188,
#  'awful': 17433,
#  'cant': 31977,
#  'encouraged': 62861,
#  'positive': 151632,
#  'comments': 41121,
#  'looking': 115680,
#  'forward': 76262,
#  'mistake': 126366,
#  '950': 4351,
#  'films': 72699,
#  'worst': 217856,
#  'pacing': 143370,
#  'storyline': 186246,
#  'soundtrack': 181826,
#  'song': 181161,
#  'lame': 110074,
#  'country': 44840,
#  'tune': 202512,
#  'played': 149499,
#  'less': 112558,
#  'four': 76396,
#  'looks': 115715,
#  'cheap': 35916,
#  'extreme': 68207,
#  'rarely': 158378,
#  'happy': 88024,
#  'end': 62887,
#  'credits': 46017,
#  'prevents': 153516,
#  'giving': 81849,
#  '1score': 1971,
#  'harvey': 88558,
#  'keitel': 106787,
#  'least': 111739,
#  'making': 118676,
#  'bit': 23867,
#  'effort': 61166,
#  'obsessives': 137703,
#  'gut': 86063,
#  'wrenching': 218178,
#  'laughter': 111199,
#  'hell': 89994,
#  'mom': 127080,
#  'liked': 113725,
#  'itgreat': 102479,
#  'camp': 31567,
#  'phil': 147668,
#  'alien': 9216,
#  'quirky': 157233,
#  'humour': 95549,
#  'based': 19765,
#  'oddness': 138043,
#  'everything': 66217,
#  'actual': 6522,
#  'punchlinesat': 156004,
#  'odd': 138009,
#  'progressed': 154507,
#  'didnt': 53322,
#  'jokes': 104889,
#  'anymoreits': 13019,
#  'low': 116577,
#  'budget': 29319,
#  'thats': 194331,
#  'problem': 153965,
#  'eventually': 65909,
#  'lost': 116006,
#  'interesti': 100466,
#  'imagine': 97202,
#  'stoner': 185856,
#  'currently': 47572,
#  'partakingfor': 144646,
#  'something': 180946,
#  'better': 22735,
#  'try': 202242,
#  'brother': 28758,
#  'planet': 149263,
#  '12': 473,
#  'came': 31392,
#  'recall': 159650,
#  'scariest': 169139,
#  'scene': 169302,
#  'bird': 23731,
#  'eating': 60477,
#  'men': 123277,
#  'dangling': 48591,
#  'helplessly': 90170,
#  'parachutes': 144172,
#  'horror': 94057,
#  'horroras': 94069,
#  'cheesy': 36157,
#  'saturday': 168551,
#  'afternoons': 7666,
#  'tired': 198206,
#  'formula': 76056,
#  'monster': 127591,
#  'type': 203457,
#  'movies': 129665,
#  'usually': 207448,
#  'included': 98210,
#  'hero': 90796,
#  'beautiful': 20668,
#  'woman': 216666,
#  'might': 124724,
#  'daughter': 49051,
#  'professor': 154389,
#  'resolution': 162386,
#  'died': 53396,
#  'care': 32399,
#  'much': 130323,
#  'romantic': 165474,
#  'angle': 11755,
#  'year': 219326,
#  'predictable': 152749,
#  'plots': 149993,
#  'unintentional': 205605,
#  'humorbut': 95481,
#  'later': 110803,
#  'psycho': 155553,
#  'loved': 116329,
#  'star': 184363,
#  'janet': 103508,
#  'leigh': 112210,
#  'bumped': 29819,
#  'early': 60169,
#  'sat': 168394,
#  'took': 199250,
#  'notice': 136310,
#  'since': 177547,
#  'screenwriters': 170763,
#  'scary': 169178,
#  'possible': 151704,
#  'wellworn': 213839,
#  'rules': 166545,
#  'im': 97111,
#  'fan': 69503,
#  'bolls': 25730,
#  'enjoyed': 63689,
#  'postal': 151783,
#  'maybe': 121539,
#  'boll': 25714,
#  'apparently': 13562,
#  'bought': 26908,
#  'rights': 164071,
#  'cry': 47057,
#  'long': 115427,
#  'ago': 8188,
#  'game': 79165,
#  'finsished': 73425,
#  'killing': 107695,
#  'mercs': 123616,
#  'infiltrating': 99077,
#  'secret': 171537,
#  'research': 162237,
#  'labs': 109667,
#  'located': 115052,
#  'tropical': 201887,
#  'island': 101821,
#  'warned': 211523,
#  'schemed': 169694,
#  'together': 198680,
#  'along': 10096,
#  'legion': 112127,
#  'schmucks': 169842,
#  'feeling': 70997,
#  'loneley': 115400,
#  'invites': 101240,
#  'three': 196662,
#  'countrymen': 44873,
#  'players': 149525,
#  'names': 132136,
#  'til': 197431,
#  'schweiger': 170084,
#  'udo': 203694,
#  'kier': 107476,
#  'ralf': 157934,
#  'moellerthree': 126910,
#  'actually': 6531,
#  'selfs': 172517,
#  'biz': 24004,
#  'tale': 191540,
#  'jack': 103170,
#  'carver': 33142,
#  'yes': 219661,
#  'german': 80764,
#  'hail': 86688,
#  'bratwurst': 27661,
#  'dudes': 59093,
#  'however': 94858,
#  'tils': 197454,
#  'badass': 18227,
#  'complained': 41581,
#  'hes': 91059,
#  'staying': 184928,
#  'true': 202032,
#  'whole': 214967,
#  'perspective': 147209,
#  'dont': 56960,
#  'looked': 115659,
#  'kicking': 107259,
#  'beyond': 23049,
#  'demented': 51163,
#  'evil': 66346,
#  'mad': 117814,
#  'scientist': 170138,
#  'dr': 57830,
#  'krieger': 109151,
#  'geneticallymutatedsoldiers': 80364,
#  'gms': 82257,
#  'performing': 146777,
#  'topsecret': 199558,
#  'reminds': 161502,
#  'spoiler': 183137,
#  'vancouver': 208013,
#  'reason': 159393,
#  'palm': 143810,
#  'trees': 201219,
#  'rich': 163625,
#  'lumberjackwoods': 117056,
#  'havent': 88908,
#  'gone': 82876,
#  'started': 184615,
#  'mehehe': 122881,
#  'cannot': 31929,
#  'stay': 184917,
#  'shenanigans': 175121,
#  'delivers': 51028,
#  'meaning': 122293,
#  'suckthere': 188477,
#  'mentioning': 123501,
#  'imply': 97655,
#  'areas': 14225,
#  'boat': 25319,
#  'cromedalbino': 46644,
#  'squad': 183711,
#  'enters': 64046,
#  'laugh': 111021,
#  'reeks': 160313,
#  'scheisse': 169679,
#  'poop': 151072,
#  'simpletons': 177458,
#  'take': 191435,
#  'wiff': 215382,
#  'ahead': 8371,
#  'btw': 29142,
#  'annoying': 12179,
#  'sidekick': 176867,
#  'shoot': 175719,
#  'minutes': 125665,
#  'screen': 170559,
#  'shakespeareshakespeare': 174481,
#  'losti': 116028,
#  'appreciate': 13804,
#  'trying': 202258,
#  'shakespeare': 174462,
#  'masses': 120770,
#  'ruin': 166489,
#  'goodis': 83090,
#  'scottish': 170405,
#  'certain': 34524,
#  'rev': 163019,
#  'bowdler': 27027,
#  'hence': 90262,
#  'bowdlerization': 27030,
#  'tried': 201510,
#  'victorian': 209106,
#  'erain': 64791,
#  'words': 217197,
#  'improve': 97875,
#  'perfectioni': 146516,
#  'write': 218253,
#  'ten': 193315,
#  'text': 194010,
#  'english': 63520,
#  'composition': 41782,
#  'forte': 76156,
#  'keep': 106730,
#  'saying': 168826,
#  'cut': 47716,
#  'fantastic': 69713,
#  'prisoners': 153820,
#  'famous': 69485,
#  'george': 80678,
#  'clooney': 39136,
#  'roll': 165295,
#  'man': 119044,
#  'constant': 42929,
#  'sorrow': 181551,
#  'recommand': 159861,
#  'everybody': 66143,
#  'greetings': 84725,
#  'bart': 19692,
#  'kind': 107815,
#  'drawn': 58159,
#  'erotic': 64946,
#  'amateurish': 10568,
#  'unbelievable': 204262,
#  'bits': 23939,
#  'sort': 181578,
#  'school': 169892,
#  'project': 154559,
#  'rosanna': 165785,
#  'arquette': 14776,
#  'thinking': 195834,
#  'stock': 185709,
#  'bizarre': 24006,
#  'supposed': 189550,
#  'midwest': 124696,
#  'town': 200118,
#  'involved': 101254,
#  'lessons': 112623,
#  'learned': 111695,
#  'insights': 99782,
#  'stilted': 185555,
#  'quite': 157248,
#  'ridiculous': 163829,
#  'lots': 116096,
#  'skin': 178416,
#  'intrigues': 100977,
#  'videotaped': 209236,
#  'nonsensewhat': 135652,
#  'bisexual': 23836,
#  'relationship': 161014,
#  'nowhere': 136805,
#  'heterosexual': 91123,
#  'encounters': 62850,
#  'absurd': 5081,
#  'dance': 48418,
#  'stereotyped': 185254,
#  'pass': 144955,
#  'million': 125030,
#  'miles': 124881,
#  'wasted': 211901,
#  'could': 44646,
#  'spent': 182700,
#  'starving': 184704,
#  'aids': 8490,
#  'africa': 7568,
#  'simply': 177485,
#  'remade': 161316,
#  'fails': 68978,
#  'capture': 32248,
#  'flavor': 74201,
#  'terror': 193774,
#  '1963': 1487,
#  'title': 198290,
#  'liam': 113009,
#  'neeson': 133163,
#  'excellent': 66669,
#  'always': 10451,
#  'holds': 92956,
#  'exception': 66732,
#  'owen': 143086,
#  'wilson': 215680,
#  'feel': 70978,
#  'character': 35192,
#  'luke': 117018,
#  'major': 118543,
#  'fault': 70519,
#  'version': 208719,
#  'strayed': 186733,
#  'shirley': 175476,
#  'jackson': 103238,
#  'attempts': 16238,
#  'grandiose': 84107,
#  'thrill': 196770,
#  'earlier': 60139,
#  'trade': 200349,
#  'snazzier': 179882,
#  'special': 182404,
#  'effects': 61055,
#  'enjoy': 63626,
#  'friction': 77292,
#  'older': 139082,
#  'top': 199429,
#  'horrible': 93975,
#  'wasnt': 211827,
#  'continuous': 43287,
#  'minute': 125651,
#  'fight': 71889,
#  'chance': 34863,
#  'development': 52601,
#  'busy': 30348,
#  'running': 166674,
#  'sword': 190690,
#  'emotional': 62550,
#  'attachment': 16167,
#  'except': 66726,
#  'machine': 117656,
#  'wanted': 211300,
#  'destroy': 52301,
#  'blatantly': 24458,
#  'stolen': 185773,
#  'lotr': 116092,
#  'wars': 211640,
#  'matrix': 121219,
#  'examplesthe': 66599,
#  'ghost': 81079,
#  'final': 73106,
#  'yoda': 219841,
#  'obee': 137482,
#  'vader': 207647,
#  'spider': 182755,
#  'beginning': 21293,
#  'frodo': 77611,
#  'attacked': 16176,
#  'return': 162945,
#  'kings': 107931,
#  'elijah': 61929,
#  'wood': 216966,
#  'victim': 209034,
#  'waitit': 210906,
#  'hypnotizes': 96141,
#  'stings': 185588,
#  'wraps': 218142,
#  'upuh': 207052,
#  'helloand': 90058,
#  'vs': 210599,
#  'humans': 95383,
#  'matrixor': 121231,
#  'terminatorthere': 193597,
#  'examples': 66587,
#  'someone': 180898,
#  'tell': 193169,
#  'nazis': 132772,
#  'juvenile': 105828,
#  'line': 114053,
#  'rushed': 166759,
#  'conclusion': 42091,
#  'childrens': 36697,
#  'adult': 7069,
#  'either': 61509,
#  'disappointment': 54658,
#  'save': 168660,
#  'remember': 161435,
#  'filmit': 72443,
#  'cinema': 37712,
#  'dark': 48763,
#  'places': 149111,
#  'nervous': 133535,
#  '7475': 3895,
#  'dad': 48057,
#  ...}

# %%
bow[0].toarray()
# Out:
# array([[0, 0, 0, ..., 0, 0, 0]])

# %%
bow.shape
# Out:
# (50000, 221399)

# %%
print(bow)
# Out:
#   (0, 139493)	1
#   (0, 163208)	1
#   (0, 123484)	1
#   (0, 212112)	2
#   (0, 143239)	5
#   (0, 64541)	2
#   (0, 220085)	1
#   (0, 93682)	1
#   (0, 163980)	2
#   (0, 66499)	1
#   (0, 87829)	1
#   (0, 124089)	1
#   (0, 73580)	2
#   (0, 195593)	1
#   (0, 187144)	2
#   (0, 29026)	1
#   (0, 205255)	1
#   (0, 169441)	1
#   (0, 209793)	4
#   (0, 173770)	1
#   (0, 217165)	1
#   (0, 82283)	1
#   (0, 202166)	1
#   (0, 176147)	3
#   (0, 69036)	1
#   :	:
#   (49999, 111997)	1
#   (49999, 100368)	1
#   (49999, 67387)	1
#   (49999, 17144)	1
#   (49999, 88193)	1
#   (49999, 133136)	1
#   (49999, 98234)	1
#   (49999, 97612)	1
#   (49999, 69619)	1
#   (49999, 14912)	1
#   (49999, 201241)	1
#   (49999, 108049)	1
#   (49999, 183119)	1
#   (49999, 121817)	1
#   (49999, 161739)	1
#   (49999, 64582)	1
#   (49999, 30862)	1
#   (49999, 134546)	1
#   (49999, 35067)	1
#   (49999, 67472)	1
#   (49999, 83313)	1
#   (49999, 161706)	1
#   (49999, 130505)	1
#   (49999, 46413)	1
#   (49999, 219952)	1

# %% [markdown]
# # bi gram

# %%
cv2 = CountVectorizer(ngram_range=(2,2))

# %%
bow2 = cv2.fit_transform(df['review'])

# %%
cv2.vocabulary_
# Out:
# {'one reviewers': 2056050,
#  'reviewers mentioned': 2421796,
#  'mentioned watching': 1839678,
#  'watching oz': 3173830,
#  'oz episode': 2095294,
#  'episode youll': 925620,
#  'youll hooked': 3300267,
#  'hooked right': 1388879,
#  'right exactly': 2432600,
#  'exactly happened': 964225,
#  'happened methe': 1313963,
#  'methe first': 1846570,
#  'first thing': 1103451,
#  'thing struck': 2925762,
#  'struck oz': 2800962,
#  'oz brutality': 2095260,
#  'brutality unflinching': 387318,
#  'unflinching scenes': 3066968,
#  'scenes violence': 2513007,
#  'violence set': 3132089,
#  'set right': 2586039,
#  'right word': 2434188,
#  'word go': 3251038,
#  'go trust': 1235355,
#  'trust show': 3026202,
#  'show faint': 2623062,
#  'faint hearted': 1010768,
#  'hearted timid': 1338634,
#  'timid show': 2967111,
#  'show pulls': 2624535,
#  'pulls punches': 2295504,
#  'punches regards': 2296468,
#  'regards drugs': 2373981,
#  'drugs sex': 838621,
#  'sex violence': 2592751,
#  'violence hardcore': 3131658,
#  'hardcore classic': 1319585,
#  'classic use': 523661,
#  'use wordit': 3093539,
#  'wordit called': 3251767,
#  'called oz': 412028,
#  'oz nickname': 2095357,
#  'nickname given': 1990994,
#  'given oswald': 1225372,
#  'oswald maximum': 2078752,
#  'maximum security': 1811540,
#  'security state': 2541137,
#  'state penitentary': 2758544,
#  'penitentary focuses': 2135875,
#  'focuses mainly': 1121808,
#  'mainly emerald': 1762438,
#  'emerald city': 886606,
#  'city experimental': 517247,
#  'experimental section': 985829,
#  'section prison': 2540597,
#  'prison cells': 2261466,
#  'cells glass': 457899,
#  'glass fronts': 1229338,
#  'fronts face': 1164644,
#  'face inwards': 1001886,
#  'inwards privacy': 1509913,
#  'privacy high': 2262498,
#  'high agenda': 1361003,
#  'agenda em': 88572,
#  'em city': 884686,
#  'city home': 517406,
#  'home manyaryans': 1383798,
#  'manyaryans muslims': 1790130,
#  'muslims gangstas': 1947283,
#  'gangstas latinos': 1185156,
#  'latinos christians': 1621786,
#  'christians italians': 507614,
#  'italians irish': 1519862,
#  'irish moreso': 1511079,
#  'moreso scuffles': 1896757,
#  'scuffles death': 2532469,
#  'death stares': 709741,
#  'stares dodgy': 2750471,
#  'dodgy dealings': 804965,
#  'dealings shady': 706973,
#  'shady agreements': 2596192,
#  'agreements never': 92726,
#  'never far': 1980812,
#  'far awayi': 1027256,
#  'awayi would': 231195,
#  'would say': 3272988,
#  'say main': 2496337,
#  'main appeal': 1761486,
#  'appeal show': 169944,
#  'show due': 2622865,
#  'due fact': 842391,
#  'fact goes': 1005339,
#  'goes shows': 1239911,
#  'shows wouldnt': 2631862,
#  'wouldnt dare': 3274305,
#  'dare forget': 689275,
#  'forget pretty': 1135532,
#  'pretty pictures': 2255152,
#  'pictures painted': 2172136,
#  'painted mainstream': 2101367,
#  'mainstream audiences': 1762919,
#  'audiences forget': 219048,
#  'forget charm': 1135087,
#  'charm forget': 484910,
#  'forget romanceoz': 1135580,
#  'romanceoz doesnt': 2454121,
#  'doesnt mess': 805933,
#  'mess around': 1842875,
#  'around first': 186816,
#  'first episode': 1101452,
#  'episode ever': 924556,
#  'ever saw': 953028,
#  'saw struck': 2493971,
#  'struck nasty': 2800948,
#  'nasty surreal': 1962068,
#  'surreal couldnt': 2847056,
#  'couldnt say': 630676,
#  'say ready': 2496890,
#  'ready watched': 2341491,
#  'watched developed': 3170331,
#  'developed taste': 752611,
#  'taste oz': 2881192,
#  'oz got': 2095320,
#  'got accustomed': 1256730,
#  'accustomed high': 45204,
#  'high levels': 1361441,
#  'levels graphic': 1657053,
#  'graphic violence': 1266297,
#  'violence violence': 3132280,
#  'violence injustice': 3131729,
#  'injustice crooked': 1476071,
#  'crooked guards': 663941,
#  'guards wholl': 1286357,
#  'wholl sold': 3215268,
#  'sold nickel': 2689226,
#  'nickel inmates': 1990893,
#  'inmates wholl': 1476434,
#  'wholl kill': 3215256,
#  'kill order': 1575246,
#  'order get': 2071154,
#  'get away': 1203908,
#  'away well': 231039,
#  'well mannered': 3195695,
#  'mannered middle': 1785004,
#  'middle class': 1850745,
#  'class inmates': 521479,
#  'inmates turned': 1476430,
#  'turned prison': 3034951,
#  'prison bitches': 2261435,
#  'bitches due': 321617,
#  'due lack': 842600,
#  'lack street': 1604754,
#  'street skills': 2794934,
#  'skills prison': 2664332,
#  'prison experience': 2261542,
#  'experience watching': 984567,
#  'oz may': 2095347,
#  'may become': 1811815,
#  'become comfortable': 276156,
#  'comfortable uncomfortable': 561470,
#  'uncomfortable viewingthats': 3056932,
#  'viewingthats get': 3127342,
#  'get touch': 1207960,
#  'touch darker': 2990516,
#  'darker side': 691132,
#  'wonderful little': 3245956,
#  'little production': 1697290,
#  'production filming': 2272467,
#  'filming technique': 1079566,
#  'technique unassuming': 2887993,
#  'unassuming oldtimebbc': 3054269,
#  'oldtimebbc fashion': 2047743,
#  'fashion gives': 1032205,
#  'gives comforting': 1226243,
#  'comforting sometimes': 561565,
#  'sometimes discomforting': 2699180,
#  'discomforting sense': 787006,
#  'sense realism': 2569707,
#  'realism entire': 2345219,
#  'entire piece': 920742,
#  'piece actors': 2172748,
#  'actors extremely': 59751,
#  'extremely well': 996994,
#  'well chosen': 3193813,
#  'chosen michael': 506082,
#  'michael sheen': 1849250,
#  'sheen got': 2602967,
#  'got polari': 1258291,
#  'polari voices': 2214362,
#  'voices pat': 3140511,
#  'pat truly': 2125825,
#  'truly see': 3025306,
#  'see seamless': 2546640,
#  'seamless editing': 2533934,
#  'editing guided': 864735,
#  'guided references': 1288917,
#  'references williams': 2370551,
#  'williams diary': 3223527,
#  'diary entries': 760113,
#  'entries well': 922272,
#  'well worth': 3197799,
#  'worth watching': 3268748,
#  'watching terrificly': 3174533,
#  'terrificly written': 2903590,
#  'written performed': 3282461,
#  'performed piece': 2150040,
#  'piece masterful': 2173468,
#  'masterful production': 1802861,
#  'production one': 2272866,
#  'one great': 2052898,
#  'great masters': 1271052,
#  'masters comedy': 1804089,
#  'comedy life': 557545,
#  'life realism': 1663651,
#  'realism really': 2345402,
#  'really comes': 2350339,
#  'comes home': 559892,
#  'home little': 1383734,
#  'little things': 1698108,
#  'things fantasy': 2927069,
#  'fantasy guard': 1026659,
#  'guard rather': 1285996,
#  'rather use': 2333548,
#  'use traditional': 3093393,
#  'traditional dream': 2999339,
#  'dream techniques': 830136,
#  'techniques remains': 2888155,
#  'remains solid': 2387395,
#  'solid disappears': 2691112,
#  'disappears plays': 783017,
#  'plays knowledge': 2197319,
#  'knowledge senses': 1595304,
#  'senses particularly': 2570616,
#  'particularly scenes': 2117668,
#  'scenes concerning': 2510165,
#  'concerning orton': 585336,
#  'orton halliwell': 2077318,
#  'halliwell sets': 1304085,
#  'sets particularly': 2587335,
#  'particularly flat': 2117237,
#  'flat halliwells': 1110030,
#  'halliwells murals': 1304088,
#  'murals decorating': 1939102,
#  'decorating every': 717025,
#  'every surface': 955519,
#  'surface terribly': 2843397,
#  'terribly well': 2903032,
#  'well done': 3194291,
#  'thought wonderful': 2943046,
#  'wonderful way': 3246532,
#  'way spend': 3181667,
#  'spend time': 2727327,
#  'time hot': 2959650,
#  'hot summer': 1400810,
#  'summer weekend': 2830888,
#  'weekend sitting': 3190311,
#  'sitting air': 2659197,
#  'air conditioned': 95474,
#  'conditioned theater': 587779,
#  'theater watching': 2912620,
#  'watching lighthearted': 3173457,
#  'lighthearted comedy': 1667839,
#  'comedy plot': 557899,
#  'plot simplistic': 2204355,
#  'simplistic dialogue': 2646138,
#  'dialogue witty': 759187,
#  'witty characters': 3237807,
#  'characters likable': 479922,
#  'likable even': 1669157,
#  'even well': 948371,
#  'well bread': 3193607,
#  'bread suspected': 368255,
#  'suspected serial': 2850557,
#  'serial killer': 2577344,
#  'killer may': 1577831,
#  'may disappointed': 1812149,
#  'disappointed realize': 783762,
#  'realize match': 2348299,
#  'match point': 1805180,
#  'point risk': 2210767,
#  'risk addiction': 2438303,
#  'addiction thought': 71304,
#  'thought proof': 2942380,
#  'proof woody': 2281122,
#  'woody allen': 3250321,
#  'allen still': 105603,
#  'still fully': 2771580,
#  'fully control': 1169095,
#  'control style': 609950,
#  'style many': 2812080,
#  'many us': 1789911,
#  'us grown': 3089247,
#  'grown lovethis': 1284120,
#  'lovethis id': 1740157,
#  'id laughed': 1426773,
#  'laughed one': 1624379,
#  'one woodys': 2058336,
#  'woodys comedies': 3250413,
#  'comedies years': 556399,
#  'years dare': 3291348,
#  'dare say': 689327,
#  'say decade': 2495249,
#  'decade ive': 711996,
#  'ive never': 1523521,
#  'never impressed': 1981098,
#  'impressed scarlet': 1451234,
#  'scarlet johanson': 2502779,
#  'johanson managed': 1542365,
#  'managed tone': 1780880,
#  'tone sexy': 2980530,
#  'sexy image': 2594527,
#  'image jumped': 1439333,
#  'jumped right': 1554689,
#  'right average': 2432054,
#  'average spirited': 225260,
#  'spirited young': 2730827,
#  'young womanthis': 3302571,
#  'womanthis may': 3242075,
#  'may crown': 1812062,
#  'crown jewel': 666123,
#  'jewel career': 1536326,
#  'career wittier': 433008,
#  'wittier devil': 3237740,
#  'devil wears': 754801,
#  'wears prada': 3187766,
#  'prada interesting': 2239905,
#  'interesting superman': 1497013,
#  'superman great': 2835284,
#  'great comedy': 1269507,
#  'comedy go': 557265,
#  'go see': 1234892,
#  'see friends': 2543925,
#  'basically theres': 262818,
#  'theres family': 2918900,
#  'family little': 1019038,
#  'little boy': 1694957,
#  'boy jake': 361087,
#  'jake thinks': 1527301,
#  'thinks theres': 2934563,
#  'theres zombie': 2920100,
#  'zombie closet': 3309108,
#  'closet parents': 536434,
#  'parents fighting': 2108810,
#  'fighting timethis': 1061832,
#  'timethis movie': 2966904,
#  'movie slower': 1918202,
#  'slower soap': 2674748,
#  'soap opera': 2685088,
#  'opera suddenly': 2065638,
#  'suddenly jake': 2824403,
#  'jake decides': 1527208,
#  'decides become': 715305,
#  'become rambo': 277007,
#  'rambo kill': 2323622,
#  'kill zombieok': 1575729,
#  'zombieok first': 3309557,
#  'first youre': 1103819,
#  'youre going': 3303784,
#  'going make': 1242067,
#  'make film': 1765991,
#  'film must': 1072388,
#  'must decide': 1947773,
#  'decide thriller': 714630,
#  'thriller drama': 2947681,
#  'drama drama': 825245,
#  'drama movie': 825686,
#  'movie watchable': 1920045,
#  'watchable parents': 3169728,
#  'parents divorcing': 2108734,
#  'divorcing arguing': 800966,
#  'arguing like': 182269,
#  'like real': 1677149,
#  'real life': 2343147,
#  'life jake': 1662661,
#  'jake closet': 1527198,
#  'closet totally': 536477,
#  'totally ruins': 2989881,
#  'ruins film': 2465975,
#  'film expected': 1069219,
#  'expected see': 982010,
#  'see boogeyman': 2542373,
#  'boogeyman similar': 346288,
#  'similar movie': 2643332,
#  'movie instead': 1914249,
#  'instead watched': 1486192,
#  'watched drama': 3170369,
#  'drama meaningless': 825658,
#  'meaningless thriller': 1821781,
#  'thriller spots3': 2948181,
#  'spots3 10': 2737397,
#  '10 well': 1195,
#  'well playing': 3196284,
#  'playing parents': 2195455,
#  'parents descent': 2108707,
#  'descent dialogs': 738312,
#  'dialogs shots': 757718,
#  'shots jake': 2619832,
#  'jake ignore': 1527230,
#  'petter matteis': 2161587,
#  'matteis love': 1808329,
#  'love time': 1735843,
#  'time money': 2960441,
#  'money visually': 1888143,
#  'visually stunning': 3137280,
#  'stunning film': 2808195,
#  'film watch': 1076796,
#  'watch mr': 3167955,
#  'mr mattei': 1929113,
#  'mattei offers': 1808310,
#  'offers us': 2035866,
#  'us vivid': 3091017,
#  'vivid portrait': 3138247,
#  'portrait human': 2224950,
#  'human relations': 1413454,
#  'relations movie': 2378479,
#  'movie seems': 1917791,
#  'seems telling': 2556546,
#  'telling us': 2895003,
#  'us money': 3089834,
#  'money power': 1887635,
#  'power success': 2237392,
#  'success people': 2820953,
#  'people different': 2137686,
#  'different situations': 767556,
#  'situations encounter': 2660788,
#  'encounter variation': 893081,
#  'variation arthur': 3107624,
#  'arthur schnitzlers': 192757,
#  'schnitzlers play': 2515058,
#  'play theme': 2190183,
#  'theme director': 2914505,
#  'director transfers': 779566,
#  'transfers action': 3004300,
#  'action present': 54910,
#  'present time': 2249817,
#  'time new': 2960588,
#  'new york': 1985137,
#  'york different': 3298920,
#  'different characters': 766435,
#  'characters meet': 480090,
#  'meet connect': 1827384,
#  'connect one': 592995,
#  'one connected': 2051087,
#  'connected one': 593184,
#  'one way': 2058147,
#  'way another': 3177851,
#  'another next': 153376,
#  'next person': 1987683,
#  'person one': 2155863,
#  'one seems': 2056384,
#  'seems know': 2555511,
#  'know previous': 1593165,
#  'previous point': 2256779,
#  'point contact': 2209435,
#  'contact stylishly': 602140,
#  'stylishly film': 2813361,
#  'film sophisticated': 1075091,
#  'sophisticated luxurious': 2707750,
#  'luxurious look': 1747910,
#  'look taken': 1716894,
#  'taken see': 2867548,
#  'see people': 2545908,
#  'people live': 2138895,
#  'live world': 1700118,
#  'world live': 3261703,
#  'live habitatthe': 1699286,
#  'habitatthe thing': 1298342,
#  'thing one': 2925149,
#  'one gets': 2052762,
#  'gets souls': 1210373,
#  'souls picture': 2712851,
#  'picture different': 2170523,
#  'different stages': 767609,
#  'stages loneliness': 2742731,
#  'loneliness one': 1710592,
#  'one inhabits': 2053501,
#  'inhabits big': 1474307,
#  'big city': 311608,
#  'city exactly': 517239,
#  'exactly best': 963940,
#  'best place': 301927,
#  'place human': 2181132,
#  'relations find': 2378438,
#  'find sincere': 1092933,
#  'sincere fulfillment': 2651506,
#  'fulfillment one': 1167101,
#  'one discerns': 2051664,
#  'discerns case': 786597,
#  'case people': 442866,
#  'people encounterthe': 2137891,
#  'encounterthe acting': 893449,
#  'acting good': 51495,
#  'good mr': 1249322,
#  'mr matteis': 1929114,
#  'matteis direction': 1808327,
#  'direction steve': 776252,
#  'steve buscemi': 2767807,
#  'buscemi rosario': 400567,
#  'rosario dawson': 2459104,
#  'dawson carol': 697781,
#  'carol kane': 436566,
#  'kane michael': 1559032,
#  'michael imperioli': 1848927,
#  'imperioli adrian': 1447238,
#  'adrian grenier': 77011,
#  'grenier rest': 1276454,
#  'rest talented': 2410886,
#  'talented cast': 2872560,
#  'cast make': 446423,
#  'make characters': 1765336,
#  'characters come': 478408,
#  'come alivewe': 552951,
#  'alivewe wish': 104649,
#  'wish mr': 3231337,
#  'mattei good': 1808297,
#  'good luck': 1249009,
#  'luck await': 1743681,
#  'await anxiously': 226712,
#  'anxiously next': 158783,
#  'next work': 1988099,
#  'probably alltime': 2263435,
#  'alltime favorite': 108361,
#  'favorite movie': 1039285,
#  'movie story': 1918634,
#  'story selflessness': 2786405,
#  'selflessness sacrifice': 2564929,
#  'sacrifice dedication': 2474450,
#  'dedication noble': 717492,
#  'noble cause': 1996869,
#  'cause preachy': 454194,
#  'preachy boring': 2241409,
#  'boring never': 352969,
#  'never gets': 1980945,
#  'gets old': 1209889,
#  'old despite': 2044487,
#  'despite seen': 746088,
#  'seen 15': 2556927,
#  '15 times': 4633,
#  'times last': 2965266,
#  'last 25': 1616429,
#  '25 years': 19308,
#  'years paul': 3292400,
#  'paul lukas': 2129745,
#  'lukas performance': 1745469,
#  'performance brings': 2145673,
#  'brings tears': 377981,
#  'tears eyes': 2886582,
#  'eyes bette': 998890,
#  'bette davis': 304308,
#  'davis one': 697311,
#  'one truly': 2057722,
#  'truly sympathetic': 3025424,
#  'sympathetic roles': 2859485,
#  'roles delight': 2451100,
#  'delight kids': 725075,
#  'kids grandma': 1573051,
#  'grandma says': 1264734,
#  'says like': 2499620,
#  'like dressedup': 1672310,
#  'dressedup midgets': 832245,
#  'midgets children': 1851648,
#  'children makes': 499434,
#  'makes fun': 1769983,
#  'fun watch': 1171222,
#  'watch mothers': 3167909,
#  'mothers slow': 1902982,
#  'slow awakening': 2673894,
#  'awakening whats': 227154,
#  'whats happening': 3206686,
#  'happening world': 1314999,
#  'world roof': 3262355,
#  'roof believable': 2456146,
#  'believable startling': 290205,
#  'startling dozen': 2756568,
#  'dozen thumbs': 822019,
#  'thumbs theyd': 2953025,
#  'theyd movie': 2920673,
#  'sure would': 2842462,
#  'would like': 3271969,
#  'like see': 1677786,
#  'see resurrection': 2546412,
#  'resurrection dated': 2413922,
#  'dated seahunt': 693600,
#  'seahunt series': 2533715,
#  'series tech': 2579794,
#  'tech today': 2887152,
#  'today would': 2973342,
#  'would bring': 3270244,
#  'bring back': 376380,
#  'back kid': 238973,
#  'kid excitement': 1570523,
#  'excitement mei': 973079,
#  'mei grew': 1829787,
#  'grew black': 1276545,
#  'black white': 325213,
#  'white tv': 3212662,
#  'tv seahunt': 3038928,
#  'seahunt gunsmoke': 2533714,
#  'gunsmoke heros': 1292150,
#  'heros every': 1355171,
#  'every weekyou': 955711,
#  'weekyou vote': 3190794,
#  'vote comeback': 3142057,
#  'comeback new': 555063,
#  'new sea': 1984601,
#  'sea huntwe': 2533108,
#  'huntwe need': 1420422,
#  'need change': 1971016,
#  'change pace': 468433,
#  'pace tv': 2096272,
#  'tv would': 3039310,
#  'would work': 3273949,
#  'work world': 3256391,
#  'world water': 3262980,
#  'water adventureoh': 3175217,
#  'adventureoh way': 79670,
#  'way thank': 3181963,
#  'thank outlet': 2907625,
#  'outlet like': 2083927,
#  'like view': 1679704,
#  'view many': 3123414,
#  'many viewpoints': 1789947,
#  'viewpoints tv': 3127495,
#  'tv many': 3038571,
#  'many moviesso': 1788714,
#  'moviesso ole': 1926429,
#  'ole way': 2047805,
#  'way believe': 3178061,
#  'believe ive': 291433,
#  'ive got': 1523409,
#  'got wanna': 1258995,
#  'wanna saywould': 3151497,
#  'saywould nice': 2500284,
#  'nice read': 1989305,
#  'read plus': 2339559,
#  'plus points': 2207241,
#  'points sea': 2213183,
#  'sea huntif': 2533106,
#  'huntif rhymes': 1420137,
#  'rhymes would': 2425566,
#  'would 10': 3269776,
#  '10 lines': 764,
#  'lines would': 1689121,
#  'would let': 3271954,
#  'let submitor': 1653971,
#  'submitor leave': 2815930,
#  'leave doubt': 1638722,
#  'doubt quitif': 819009,
#  'quitif must': 2316260,
#  'must go': 1948083,
#  'go lets': 1234151,
#  'show amazing': 2621963,
#  'amazing fresh': 128846,
#  'fresh innovative': 1157299,
#  'innovative idea': 1477816,
#  'idea 70s': 1427099,
#  '70s first': 25808,
#  'first aired': 1100605,
#  'aired first': 96295,
#  'first years': 1103812,
#  'years brilliant': 3291106,
#  'brilliant things': 375732,
#  'things dropped': 2926944,
#  'dropped 1990': 836768,
#  '1990 show': 14248,
#  'show really': 2624606,
#  'really funny': 2351211,
#  'funny anymore': 1173183,
#  'anymore continued': 159305,
#  'continued decline': 606193,
#  'decline complete': 716674,
#  'complete waste': 577479,
#  'waste time': 3164655,
#  'time todayits': 2962495,
#  'todayits truly': 2973411,
#  'truly disgraceful': 3024610,
#  'disgraceful far': 790477,
#  'far show': 1028692,
#  'show fallen': 2623069,
#  'fallen writing': 1014816,
#  'writing painfully': 3281100,
#  'painfully bad': 2100735,
#  'bad performances': 245620,
#  'performances almost': 2148146,
#  'almost bad': 109308,
#  'bad mildly': 245273,
#  'mildly entertaining': 1855170,
#  'entertaining respite': 918205,
#  'respite guesthosts': 2408780,
#  'guesthosts show': 1288260,
#  'show probably': 2624475,
#  'probably wouldnt': 2265196,
#  'wouldnt still': 3274731,
#  'still air': 2770581,
#  'air find': 95595,
#  'find hard': 1091661,
#  'hard believe': 1318211,
#  'believe creator': 290869,
#  'creator handselected': 652499,
#  'handselected original': 1310155,
#  'original cast': 2073888,
#  'cast also': 445173,
#  'also chose': 117187,
#  'chose band': 505673,
#  'band hacks': 252732,
#  'hacks followed': 1298994,
#  'followed one': 1124718,
#  'one recognize': 2055868,
#  'recognize brilliance': 2361849,
#  'brilliance see': 374623,
#  'see fit': 2543814,
#  'fit replace': 1105724,
#  'replace mediocrity': 2398315,
#  'mediocrity felt': 1826600,
#  'felt must': 1052585,
#  'must give': 1948080,
#  'give stars': 1224051,
#  'stars respect': 2753080,
#  'respect original': 2407848,
#  'cast made': 446414,
#  'made show': 1755927,
#  'show huge': 2623519,
#  'huge success': 1411561,
#  'success show': 2821068,
#  'show awful': 2622099,
#  'awful cant': 232335,
#  'cant believe': 423587,
#  'believe still': 292246,
#  'encouraged positive': 893590,
#  'positive comments': 2229065,
#  'comments film': 566590,
#  'film looking': 1071719,
#  'looking forward': 1718779,
#  'forward watching': 1143148,
#  'watching film': 3172865,
#  'film bad': 1066490,
#  'bad mistake': 245287,
#  'mistake ive': 1874639,
#  'ive seen': 1523638,
#  'seen 950': 2557004,
#  '950 films': 29596,
#  'films truly': 1085919,
#  'truly one': 3025152,
#  'one worst': 2058363,
#  'worst awful': 3266489,
#  'awful almost': 232214,
#  'almost every': 109770,
#  'every way': 955690,
#  'way editing': 3178992,
#  'editing pacing': 864903,
#  'pacing storyline': 2097097,
#  'storyline acting': 2787914,
#  'acting soundtrack': 52879,
#  'soundtrack films': 2715134,
#  'films song': 1085476,
#  'song lame': 2703894,
#  'lame country': 1609218,
#  'country tune': 633751,
#  'tune played': 3031153,
#  'played less': 2191939,
#  'less four': 1650721,
#  'four times': 1146888,
#  'times film': 2964906,
#  'film looks': 1071721,
#  'looks cheap': 1720267,
#  'cheap nasty': 488592,
#  'nasty boring': 1961707,
#  'boring extreme': 352552,
#  'extreme rarely': 996131,
#  'rarely happy': 2329483,
#  'happy see': 1317533,
#  'see end': 2543474,
#  'end credits': 894457,
#  'credits film': 655146,
#  'film thing': 1075931,
#  'thing prevents': 2925301,
#  'prevents giving': 2256168,
#  'giving 1score': 1227281,
#  '1score harvey': 15715,
#  'harvey keitel': 1324743,
#  'keitel far': 1565034,
#  'far best': 1027302,
#  'best performance': 301880,
#  'performance least': 2146716,
#  'least seems': 1637725,
#  'seems making': 2555637,
#  'making bit': 1772195,
#  'bit effort': 319608,
#  'effort one': 871561,
#  'one keitel': 2053802,
#  'keitel obsessives': 1565054,
#  'like original': 1676269,
#  'original gut': 2074416,
#  'gut wrenching': 1292691,
#  'wrenching laughter': 3276927,
#  'laughter like': 1626146,
#  'like movie': 1675751,
#  'movie young': 1920418,
#  'young old': 3301894,
#  'old love': 2045292,
#  'love movie': 1734563,
#  'movie hell': 1913748,
#  'hell even': 1344599,
#  'even mom': 945795,
#  'mom liked': 1882695,
#  'liked itgreat': 1680898,
#  'itgreat camp': 1521040,
#  'phil alien': 2162959,
#  'alien one': 102697,
#  'one quirky': 2055744,
#  'quirky films': 2313812,
#  'films humour': 1083863,
#  'humour based': 1417419,
#  'based around': 259898,
#  'around oddness': 187664,
#  'oddness everything': 2032689,
#  'everything rather': 959326,
#  'rather actual': 2331170,
#  'actual punchlinesat': 64675,
#  'punchlinesat first': 2296631,
#  'first odd': 1102488,
#  'odd pretty': 2032110,
#  'pretty funny': 2254718,
#  'funny movie': 1174460,
#  'movie progressed': 1916773,
#  'progressed didnt': 2276858,
#  'didnt find': 761873,
#  'find jokes': 1091923,
#  'jokes oddness': 1546596,
#  'oddness funny': 2032692,
#  'funny anymoreits': 1173184,
#  'anymoreits low': 159694,
#  'low budget': 1740727,
#  'budget film': 390243,
#  'film thats': 1075881,
#  'thats never': 2910598,
#  'never problem': 1981636,
#  'problem pretty': 2266256,
#  'pretty interesting': 2254904,
#  'interesting characters': 1495608,
#  'characters eventually': 478979,
#  'eventually lost': 950896,
#  'lost interesti': 1725739,
#  'interesti imagine': 1495354,
#  'imagine film': 1441949,
#  'film would': 1077074,
#  'would appeal': 3269972,
#  'appeal stoner': 169960,
#  'stoner currently': 2777108,
#  'currently partakingfor': 674302,
#  'partakingfor something': 2115373,
#  'something similar': 2698058,
#  'similar better': 2642895,
#  'better try': 307517,
#  'try brother': 3027606,
#  'brother another': 382545,
#  'another planet': 153561,
#  'saw movie': 2493405,
#  'movie 12': 1908943,
#  '12 came': 3150,
#  'came recall': 415381,
#  'recall scariest': 2358502,
#  'scariest scene': 2502683,
#  'scene big': 2504880,
#  'big bird': 311383,
#  'bird eating': 317744,
#  'eating men': 860553,
#  'men dangling': 1835111,
#  'dangling helplessly': 687818,
#  'helplessly parachutes': 1348828,
#  'parachutes right': 2106598,
#  'right air': 2431948,
#  'air horror': 95665,
#  'horror horroras': 1396470,
#  'horroras young': 1397308,
#  'young kid': 3301581,
#  'kid going': 1570605,
#  'going cheesy': 1241004,
#  'cheesy films': 492608,
#  'films saturday': 1085239,
#  'saturday afternoons': 2489364,
#  'afternoons still': 86078,
#  'still tired': 2773294,
#  'tired formula': 2968675,
#  'formula monster': 1140568,
#  'monster type': 1890887,
#  'type movies': 3047595,
#  'movies usually': 1925824,
#  'usually included': 3099967,
#  'included hero': 1457353,
#  'hero beautiful': 1352709,
#  'beautiful woman': 273379,
#  'woman might': 3240620,
#  'might daughter': 1852645,
#  'daughter professor': 694913,
#  'professor happy': 2274906,
#  'happy resolution': 1317500,
#  'resolution monster': 2406429,
#  'monster died': 1890305,
#  'died end': 763854,
#  'end didnt': 894578,
#  'didnt care': 761597,
#  'care much': 431289,
#  'much romantic': 1934830,
#  'romantic angle': 2454500,
#  'angle 12': 143890,
#  '12 year': 3441,
#  'year old': 3289978,
#  'old predictable': 2045709,
#  'predictable plots': 2243780,
#  'plots love': 2205579,
#  'love unintentional': 1735987,
#  'unintentional humorbut': 3071496,
#  'humorbut year': 1416846,
#  'year later': 3289854,
#  'later saw': 1620678,
#  'saw psycho': 2493636,
#  'psycho came': 2291041,
#  'came loved': 415098,
#  'loved star': 1737433,
#  'star janet': 2749268,
#  'janet leigh': 1529057,
#  'leigh bumped': 1646690,
#  'bumped early': 396039,
#  'early film': 854417,
#  'film sat': 1074421,
#  'sat took': 2487409,
#  'took notice': 2982789,
#  'notice point': 2012071,
#  'point since': 2210911,
#  'since screenwriters': 2650898,
#  'screenwriters making': 2528467,
#  'making story': 1773633,
#  'story make': 2785090,
#  'make scary': 1767521,
#  'scary possible': 2503582,
#  'possible wellworn': 2231610,
#  'wellworn formula': 3200298,
#  'formula rules': 1140628,
#  'im big': 1437684,
#  'big fan': 311941,
#  'fan bolls': 1021642,
#  'bolls work': 343095,
#  'work many': 3254907,
#  'many enjoyed': 1787718,
#  'enjoyed movie': 910532,
#  'movie postal': 1916587,
#  'postal maybe': 2232776,
#  'maybe im': 1814652,
#  'im one': 1438467,
#  'one boll': 2050354,
#  'boll apparently': 342920,
#  'apparently bought': 168464,
#  'bought rights': 357815,
#  'rights use': 2434880,
#  'use far': 3092216,
#  'far cry': 1027516,
#  'cry long': 668483,
#  'long ago': 1711098,
#  'ago even': 90743,
#  'even game': 944439,
#  'game even': 1182202,
#  'even finsished': 944258,
#  'finsished people': 1098539,
#  'people enjoyed': 2137911,
#  'enjoyed killing': 910419,
#  'killing mercs': 1579341,
#  'mercs infiltrating': 1840692,
#  'infiltrating secret': 1471079,
#  'secret research': 2539600,
#  'research labs': 2404083,
#  'labs located': 1603764,
#  'located tropical': 1706533,
#  'tropical island': 3020375,
#  'island warned': 1514977,
#  'warned far': 3159653,
#  'cry something': 668616,
#  'something mr': 2697466,
#  'mr boll': 1928417,
#  'boll schemed': 343017,
#  'schemed together': 2514147,
#  'together along': 2974256,
#  'along legion': 113434,
#  'legion schmucks': 1646001,
#  'schmucks feeling': 2514924,
#  'feeling loneley': 1048409,
#  'loneley set': 1710507,
#  'set mr': 2585723,
#  'boll invites': 342986,
#  'invites three': 1507040,
#  'three countrymen': 2945537,
#  'countrymen play': 633902,
#  'play players': 2189683,
#  'players go': 2193785,
#  'go names': 1234351,
#  'names til': 1958675,
#  'til schweiger': 2956339,
#  'schweiger udo': 2517692,
#  'udo kier': 3050234,
#  'kier ralf': 1574202,
#  ...}

# %%
bow2[0].toarray()
# Out:
# array([[0, 0, 0, ..., 0, 0, 0]])

# %% [markdown]
# # if we use (1,2)
# both bi gram and unigram
# # id we use (1,3)
# we use all unigram bigram trigram

# %% [markdown]
# # tfIDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfid = TfidfVectorizer()

# %%
tf = tfid.fit_transform(df['review'])

# %%
tfid.vocabulary_
# Out:
# {'one': 139493,
#  'reviewers': 163208,
#  'mentioned': 123484,
#  'watching': 212112,
#  'oz': 143239,
#  'episode': 64541,
#  'youll': 220085,
#  'hooked': 93682,
#  'right': 163980,
#  'exactly': 66499,
#  'happened': 87829,
#  'methe': 124089,
#  'first': 73580,
#  'thing': 195593,
#  'struck': 187144,
#  'brutality': 29026,
#  'unflinching': 205255,
#  'scenes': 169441,
#  'violence': 209793,
#  'set': 173770,
#  'word': 217165,
#  'go': 82283,
#  'trust': 202166,
#  'show': 176147,
#  'faint': 69036,
#  'hearted': 89458,
#  'timid': 198062,
#  'pulls': 155907,
#  'punches': 155990,
#  'regards': 160605,
#  'drugs': 58777,
#  'sex': 174036,
#  'hardcore': 88126,
#  'classic': 38397,
#  'use': 207262,
#  'wordit': 217184,
#  'called': 31237,
#  'nickname': 134175,
#  'given': 81823,
#  'oswald': 141361,
#  'maximum': 121508,
#  'security': 171641,
#  'state': 184726,
#  'penitentary': 146129,
#  'focuses': 74986,
#  'mainly': 118473,
#  'emerald': 62419,
#  'city': 38093,
#  'experimental': 67616,
#  'section': 171606,
#  'prison': 153800,
#  'cells': 34270,
#  'glass': 81949,
#  'fronts': 77723,
#  'face': 68624,
#  'inwards': 101315,
#  'privacy': 153858,
#  'high': 91353,
#  'agenda': 8031,
#  'em': 62259,
#  'home': 93262,
#  'manyaryans': 119746,
#  'muslims': 131380,
#  'gangstas': 79388,
#  'latinos': 110948,
#  'christians': 37299,
#  'italians': 102211,
#  'irish': 101440,
#  'moreso': 128208,
#  'scuffles': 171041,
#  'death': 49747,
#  'stares': 184417,
#  'dodgy': 56257,
#  'dealings': 49679,
#  'shady': 174392,
#  'agreements': 8307,
#  'never': 133690,
#  'far': 69852,
#  'awayi': 17317,
#  'would': 217980,
#  'say': 168784,
#  'main': 118452,
#  'appeal': 13585,
#  'due': 59125,
#  'fact': 68779,
#  'goes': 82565,
#  'shows': 176338,
#  'wouldnt': 218000,
#  'dare': 48725,
#  'forget': 75794,
#  'pretty': 153459,
#  'pictures': 148247,
#  'painted': 143631,
#  'mainstream': 118486,
#  'audiences': 16541,
#  'charm': 35683,
#  'romanceoz': 165428,
#  'doesnt': 56318,
#  'mess': 123836,
#  'around': 14699,
#  'ever': 65925,
#  'saw': 168719,
#  'nasty': 132434,
#  'surreal': 189884,
#  'couldnt': 44663,
#  'ready': 158980,
#  'watched': 212066,
#  'developed': 52584,
#  'taste': 192232,
#  'got': 83650,
#  'accustomed': 5535,
#  'levels': 112856,
#  'graphic': 84208,
#  'injustice': 99436,
#  'crooked': 46682,
#  'guards': 85484,
#  'wholl': 215013,
#  'sold': 180656,
#  'nickel': 134149,
#  'inmates': 99479,
#  'kill': 107539,
#  'order': 140801,
#  'get': 80899,
#  'away': 17278,
#  'well': 213322,
#  'mannered': 119499,
#  'middle': 124530,
#  'class': 38379,
#  'turned': 202692,
#  'bitches': 23882,
#  'lack': 109702,
#  'street': 186773,
#  'skills': 178381,
#  'experience': 67530,
#  'may': 121529,
#  'become': 20865,
#  'comfortable': 40879,
#  'uncomfortable': 204436,
#  'viewingthats': 209461,
#  'touch': 199889,
#  'darker': 48780,
#  'side': 176827,
#  'wonderful': 216850,
#  'little': 114613,
#  'production': 154250,
#  'filming': 72414,
#  'technique': 192727,
#  'unassuming': 204192,
#  'oldtimebbc': 139168,
#  'fashion': 70174,
#  'gives': 81844,
#  'comforting': 40887,
#  'sometimes': 181045,
#  'discomforting': 54866,
#  'sense': 172961,
#  'realism': 159057,
#  'entire': 64271,
#  'piece': 148324,
#  'actors': 6283,
#  'extremely': 68218,
#  'chosen': 37204,
#  'michael': 124334,
#  'sheen': 174965,
#  'polari': 150618,
#  'voices': 210320,
#  'pat': 145169,
#  'truly': 202123,
#  'see': 171699,
#  'seamless': 171193,
#  'editing': 60794,
#  'guided': 85660,
#  'references': 160412,
#  'williams': 215580,
#  'diary': 53124,
#  'entries': 64350,
#  'worth': 217909,
#  'terrificly': 193731,
#  'written': 218423,
#  'performed': 146760,
#  'masterful': 120838,
#  'great': 84454,
#  'masters': 120917,
#  'comedy': 40657,
#  'life': 113232,
#  'really': 159215,
#  'comes': 40845,
#  'things': 195681,
#  'fantasy': 69759,
#  'guard': 85463,
#  'rather': 158502,
#  'traditional': 200365,
#  'dream': 58216,
#  'techniques': 192731,
#  'remains': 161330,
#  'solid': 180730,
#  'disappears': 54546,
#  'plays': 149611,
#  'knowledge': 108581,
#  'senses': 173028,
#  'particularly': 144736,
#  'concerning': 42043,
#  'orton': 141199,
#  'halliwell': 87139,
#  'sets': 173813,
#  'flat': 74107,
#  'halliwells': 87140,
#  'murals': 130933,
#  'decorating': 50312,
#  'every': 66139,
#  'surface': 189688,
#  'terribly': 193708,
#  'done': 56811,
#  'thought': 196492,
#  'way': 212474,
#  'spend': 182689,
#  'time': 197485,
#  'hot': 94427,
#  'summer': 188833,
#  'weekend': 213041,
#  'sitting': 178018,
#  'air': 8575,
#  'conditioned': 42230,
#  'theater': 194426,
#  'lighthearted': 113590,
#  'plot': 149858,
#  'simplistic': 177479,
#  'dialogue': 52985,
#  'witty': 216473,
#  'characters': 35351,
#  'likable': 113672,
#  'even': 65807,
#  'bread': 27760,
#  'suspected': 190051,
#  'serial': 173466,
#  'killer': 107601,
#  'disappointed': 54563,
#  'realize': 159187,
#  'match': 120997,
#  'point': 150346,
#  'risk': 164358,
#  'addiction': 6697,
#  'proof': 154784,
#  'woody': 217073,
#  'allen': 9520,
#  'still': 185494,
#  'fully': 78050,
#  'control': 43415,
#  'style': 187683,
#  'many': 119742,
#  'us': 207185,
#  'grown': 85286,
#  'lovethis': 116528,
#  'id': 96407,
#  'laughed': 111074,
#  'woodys': 217077,
#  'comedies': 40632,
#  'years': 219402,
#  'decade': 50029,
#  'ive': 103057,
#  'impressed': 97763,
#  'scarlet': 169150,
#  'johanson': 104750,
#  'managed': 119053,
#  'tone': 199059,
#  'sexy': 174237,
#  'image': 97116,
#  'jumped': 105524,
#  'average': 17063,
#  'spirited': 182928,
#  'young': 220096,
#  'womanthis': 216752,
#  'crown': 46882,
#  'jewel': 104271,
#  'career': 32424,
#  'wittier': 216466,
#  'devil': 52699,
#  'wears': 212883,
#  'prada': 152429,
#  'interesting': 100471,
#  'superman': 189292,
#  'friends': 77391,
#  'basically': 19841,
#  'theres': 195328,
#  'family': 69374,
#  'boy': 27139,
#  'jake': 103408,
#  'thinks': 195879,
#  'zombie': 221075,
#  'closet': 39205,
#  'parents': 144382,
#  'fighting': 71914,
#  'timethis': 197982,
#  'movie': 129107,
#  'slower': 179266,
#  'soap': 180189,
#  'opera': 140395,
#  'suddenly': 188490,
#  'decides': 50195,
#  'rambo': 157974,
#  'zombieok': 221110,
#  'youre': 220179,
#  'going': 82640,
#  'make': 118567,
#  'film': 72077,
#  'must': 131406,
#  'decide': 50184,
#  'thriller': 196779,
#  'drama': 57960,
#  'watchable': 212008,
#  'divorcing': 55897,
#  'arguing': 14383,
#  'like': 113692,
#  'real': 159014,
#  'totally': 199826,
#  'ruins': 166506,
#  'expected': 67431,
#  'boogeyman': 26062,
#  'similar': 177347,
#  'instead': 99971,
#  'meaningless': 122310,
#  'spots3': 183496,
#  '10': 92,
#  'playing': 149569,
#  'descent': 51912,
#  'dialogs': 52971,
#  'shots': 176020,
#  'ignore': 96783,
#  'petter': 147450,
#  'matteis': 121263,
#  'love': 116277,
#  'money': 127281,
#  'visually': 210091,
#  'stunning': 187483,
#  'watch': 211996,
#  'mr': 130131,
#  'mattei': 121260,
#  'offers': 138317,
#  'vivid': 210185,
#  'portrait': 151516,
#  'human': 95301,
#  'relations': 161011,
#  'seems': 171850,
#  'telling': 193188,
#  'power': 152255,
#  'success': 188259,
#  'people': 146225,
#  'different': 53570,
#  'situations': 178054,
#  'encounter': 62838,
#  'variation': 208151,
#  'arthur': 14974,
#  'schnitzlers': 169863,
#  'play': 149467,
#  'theme': 194697,
#  'director': 54250,
#  'transfers': 200695,
#  'action': 5984,
#  'present': 153210,
#  'new': 133750,
#  'york': 219918,
#  'meet': 122733,
#  'connect': 42578,
#  'connected': 42579,
#  'another': 12274,
#  'next': 133939,
#  'person': 147067,
#  'know': 108521,
#  'previous': 153534,
#  'contact': 43045,
#  'stylishly': 187744,
#  'sophisticated': 181454,
#  'luxurious': 117297,
#  'look': 115633,
#  'taken': 191453,
#  'live': 114677,
#  'world': 217528,
#  'habitatthe': 86428,
#  'gets': 80939,
#  'souls': 181722,
#  'picture': 148189,
#  'stages': 184035,
#  'loneliness': 115403,
#  'inhabits': 99319,
#  'big': 23313,
#  'best': 22527,
#  'place': 149020,
#  'find': 73190,
#  'sincere': 177573,
#  'fulfillment': 77977,
#  'discerns': 54817,
#  'case': 33176,
#  'encounterthe': 62856,
#  'acting': 5822,
#  'good': 82930,
#  'direction': 54173,
#  'steve': 185332,
#  'buscemi': 30179,
#  'rosario': 165789,
#  'dawson': 49229,
#  'carol': 32821,
#  'kane': 106149,
#  'imperioli': 97564,
#  'adrian': 7046,
#  'grenier': 84772,
#  'rest': 162558,
#  'talented': 191564,
#  'cast': 33373,
#  'come': 40579,
#  'alivewe': 9377,
#  'wish': 216149,
#  'luck': 116863,
#  'await': 17201,
#  'anxiously': 12956,
#  'work': 217251,
#  'probably': 153941,
#  'alltime': 9829,
#  'favorite': 70614,
#  'story': 186111,
#  'selflessness': 172440,
#  'sacrifice': 167156,
#  'dedication': 50365,
#  'noble': 134793,
#  'cause': 33937,
#  'preachy': 152569,
#  'boring': 26536,
#  'old': 139059,
#  'despite': 52226,
#  'seen': 171868,
#  '15': 731,
#  'times': 197805,
#  'last': 110682,
#  '25': 2411,
#  'paul': 145455,
#  'lukas': 117013,
#  'performance': 146600,
#  'brings': 28371,
#  'tears': 192643,
#  'eyes': 68407,
#  'bette': 22733,
#  'davis': 49174,
#  'sympathetic': 190853,
#  'roles': 165188,
#  'delight': 50941,
#  'kids': 107384,
#  'grandma': 84113,
#  'says': 168883,
#  'dressedup': 58402,
#  'midgets': 124603,
#  'children': 36657,
#  'makes': 118626,
#  'fun': 78097,
#  'mothers': 128722,
#  'slow': 179244,
#  'awakening': 17217,
#  'whats': 214368,
#  'happening': 87880,
#  'roof': 165606,
#  'believable': 21704,
#  'startling': 184660,
#  'dozen': 57807,
#  'thumbs': 197147,
#  'theyd': 195475,
#  'sure': 189636,
#  'resurrection': 162754,
#  'dated': 48993,
#  'seahunt': 171163,
#  'series': 173487,
#  'tech': 192687,
#  'today': 198528,
#  'bring': 28363,
#  'back': 17901,
#  'kid': 107279,
#  'excitement': 66819,
#  'mei': 122903,
#  'grew': 84793,
#  'black': 24081,
#  'white': 214779,
#  'tv': 202846,
#  'gunsmoke': 85971,
#  'heros': 90881,
#  'weekyou': 213098,
#  'vote': 210516,
#  'comeback': 40589,
#  'sea': 171118,
#  'huntwe': 95728,
#  'need': 133084,
#  'change': 34959,
#  'pace': 143308,
#  'water': 212284,
#  'adventureoh': 7181,
#  'thank': 194102,
#  'outlet': 141939,
#  'view': 209321,
#  'viewpoints': 209484,
#  'moviesso': 129847,
#  'ole': 139181,
#  'believe': 21761,
#  'wanna': 211259,
#  'saywould': 168926,
#  'nice': 134037,
#  'read': 158916,
#  'plus': 150166,
#  'points': 150474,
#  'huntif': 95708,
#  'rhymes': 163540,
#  'lines': 114121,
#  'let': 112704,
#  'submitor': 187976,
#  'leave': 111817,
#  'doubt': 57456,
#  'quitif': 157257,
#  'lets': 112746,
#  'amazing': 10620,
#  'fresh': 77220,
#  'innovative': 99586,
#  'idea': 96416,
#  '70s': 3792,
#  'aired': 8605,
#  'brilliant': 28266,
#  'dropped': 58661,
#  '1990': 1787,
#  'funny': 78294,
#  'anymore': 12996,
#  'continued': 43249,
#  'decline': 50272,
#  'complete': 41620,
#  'waste': 211896,
#  'todayits': 198563,
#  'disgraceful': 55077,
#  'fallen': 69223,
#  'writing': 218371,
#  'painfully': 143581,
#  'bad': 18190,
#  'performances': 146673,
#  'almost': 9977,
#  'mildly': 124851,
#  'entertaining': 64085,
#  'respite': 162511,
#  'guesthosts': 85604,
#  'hard': 88107,
#  'creator': 45904,
#  'handselected': 87573,
#  'original': 140989,
#  'also': 10251,
#  'chose': 37202,
#  'band': 19049,
#  'hacks': 86495,
#  'followed': 75158,
#  'recognize': 159828,
#  'brilliance': 28253,
#  'fit': 73774,
#  'replace': 161908,
#  'mediocrity': 122634,
#  'felt': 71208,
#  'give': 81814,
#  'stars': 184518,
#  'respect': 162455,
#  'made': 117862,
#  'huge': 95188,
#  'awful': 17433,
#  'cant': 31977,
#  'encouraged': 62861,
#  'positive': 151632,
#  'comments': 41121,
#  'looking': 115680,
#  'forward': 76262,
#  'mistake': 126366,
#  '950': 4351,
#  'films': 72699,
#  'worst': 217856,
#  'pacing': 143370,
#  'storyline': 186246,
#  'soundtrack': 181826,
#  'song': 181161,
#  'lame': 110074,
#  'country': 44840,
#  'tune': 202512,
#  'played': 149499,
#  'less': 112558,
#  'four': 76396,
#  'looks': 115715,
#  'cheap': 35916,
#  'extreme': 68207,
#  'rarely': 158378,
#  'happy': 88024,
#  'end': 62887,
#  'credits': 46017,
#  'prevents': 153516,
#  'giving': 81849,
#  '1score': 1971,
#  'harvey': 88558,
#  'keitel': 106787,
#  'least': 111739,
#  'making': 118676,
#  'bit': 23867,
#  'effort': 61166,
#  'obsessives': 137703,
#  'gut': 86063,
#  'wrenching': 218178,
#  'laughter': 111199,
#  'hell': 89994,
#  'mom': 127080,
#  'liked': 113725,
#  'itgreat': 102479,
#  'camp': 31567,
#  'phil': 147668,
#  'alien': 9216,
#  'quirky': 157233,
#  'humour': 95549,
#  'based': 19765,
#  'oddness': 138043,
#  'everything': 66217,
#  'actual': 6522,
#  'punchlinesat': 156004,
#  'odd': 138009,
#  'progressed': 154507,
#  'didnt': 53322,
#  'jokes': 104889,
#  'anymoreits': 13019,
#  'low': 116577,
#  'budget': 29319,
#  'thats': 194331,
#  'problem': 153965,
#  'eventually': 65909,
#  'lost': 116006,
#  'interesti': 100466,
#  'imagine': 97202,
#  'stoner': 185856,
#  'currently': 47572,
#  'partakingfor': 144646,
#  'something': 180946,
#  'better': 22735,
#  'try': 202242,
#  'brother': 28758,
#  'planet': 149263,
#  '12': 473,
#  'came': 31392,
#  'recall': 159650,
#  'scariest': 169139,
#  'scene': 169302,
#  'bird': 23731,
#  'eating': 60477,
#  'men': 123277,
#  'dangling': 48591,
#  'helplessly': 90170,
#  'parachutes': 144172,
#  'horror': 94057,
#  'horroras': 94069,
#  'cheesy': 36157,
#  'saturday': 168551,
#  'afternoons': 7666,
#  'tired': 198206,
#  'formula': 76056,
#  'monster': 127591,
#  'type': 203457,
#  'movies': 129665,
#  'usually': 207448,
#  'included': 98210,
#  'hero': 90796,
#  'beautiful': 20668,
#  'woman': 216666,
#  'might': 124724,
#  'daughter': 49051,
#  'professor': 154389,
#  'resolution': 162386,
#  'died': 53396,
#  'care': 32399,
#  'much': 130323,
#  'romantic': 165474,
#  'angle': 11755,
#  'year': 219326,
#  'predictable': 152749,
#  'plots': 149993,
#  'unintentional': 205605,
#  'humorbut': 95481,
#  'later': 110803,
#  'psycho': 155553,
#  'loved': 116329,
#  'star': 184363,
#  'janet': 103508,
#  'leigh': 112210,
#  'bumped': 29819,
#  'early': 60169,
#  'sat': 168394,
#  'took': 199250,
#  'notice': 136310,
#  'since': 177547,
#  'screenwriters': 170763,
#  'scary': 169178,
#  'possible': 151704,
#  'wellworn': 213839,
#  'rules': 166545,
#  'im': 97111,
#  'fan': 69503,
#  'bolls': 25730,
#  'enjoyed': 63689,
#  'postal': 151783,
#  'maybe': 121539,
#  'boll': 25714,
#  'apparently': 13562,
#  'bought': 26908,
#  'rights': 164071,
#  'cry': 47057,
#  'long': 115427,
#  'ago': 8188,
#  'game': 79165,
#  'finsished': 73425,
#  'killing': 107695,
#  'mercs': 123616,
#  'infiltrating': 99077,
#  'secret': 171537,
#  'research': 162237,
#  'labs': 109667,
#  'located': 115052,
#  'tropical': 201887,
#  'island': 101821,
#  'warned': 211523,
#  'schemed': 169694,
#  'together': 198680,
#  'along': 10096,
#  'legion': 112127,
#  'schmucks': 169842,
#  'feeling': 70997,
#  'loneley': 115400,
#  'invites': 101240,
#  'three': 196662,
#  'countrymen': 44873,
#  'players': 149525,
#  'names': 132136,
#  'til': 197431,
#  'schweiger': 170084,
#  'udo': 203694,
#  'kier': 107476,
#  'ralf': 157934,
#  'moellerthree': 126910,
#  'actually': 6531,
#  'selfs': 172517,
#  'biz': 24004,
#  'tale': 191540,
#  'jack': 103170,
#  'carver': 33142,
#  'yes': 219661,
#  'german': 80764,
#  'hail': 86688,
#  'bratwurst': 27661,
#  'dudes': 59093,
#  'however': 94858,
#  'tils': 197454,
#  'badass': 18227,
#  'complained': 41581,
#  'hes': 91059,
#  'staying': 184928,
#  'true': 202032,
#  'whole': 214967,
#  'perspective': 147209,
#  'dont': 56960,
#  'looked': 115659,
#  'kicking': 107259,
#  'beyond': 23049,
#  'demented': 51163,
#  'evil': 66346,
#  'mad': 117814,
#  'scientist': 170138,
#  'dr': 57830,
#  'krieger': 109151,
#  'geneticallymutatedsoldiers': 80364,
#  'gms': 82257,
#  'performing': 146777,
#  'topsecret': 199558,
#  'reminds': 161502,
#  'spoiler': 183137,
#  'vancouver': 208013,
#  'reason': 159393,
#  'palm': 143810,
#  'trees': 201219,
#  'rich': 163625,
#  'lumberjackwoods': 117056,
#  'havent': 88908,
#  'gone': 82876,
#  'started': 184615,
#  'mehehe': 122881,
#  'cannot': 31929,
#  'stay': 184917,
#  'shenanigans': 175121,
#  'delivers': 51028,
#  'meaning': 122293,
#  'suckthere': 188477,
#  'mentioning': 123501,
#  'imply': 97655,
#  'areas': 14225,
#  'boat': 25319,
#  'cromedalbino': 46644,
#  'squad': 183711,
#  'enters': 64046,
#  'laugh': 111021,
#  'reeks': 160313,
#  'scheisse': 169679,
#  'poop': 151072,
#  'simpletons': 177458,
#  'take': 191435,
#  'wiff': 215382,
#  'ahead': 8371,
#  'btw': 29142,
#  'annoying': 12179,
#  'sidekick': 176867,
#  'shoot': 175719,
#  'minutes': 125665,
#  'screen': 170559,
#  'shakespeareshakespeare': 174481,
#  'losti': 116028,
#  'appreciate': 13804,
#  'trying': 202258,
#  'shakespeare': 174462,
#  'masses': 120770,
#  'ruin': 166489,
#  'goodis': 83090,
#  'scottish': 170405,
#  'certain': 34524,
#  'rev': 163019,
#  'bowdler': 27027,
#  'hence': 90262,
#  'bowdlerization': 27030,
#  'tried': 201510,
#  'victorian': 209106,
#  'erain': 64791,
#  'words': 217197,
#  'improve': 97875,
#  'perfectioni': 146516,
#  'write': 218253,
#  'ten': 193315,
#  'text': 194010,
#  'english': 63520,
#  'composition': 41782,
#  'forte': 76156,
#  'keep': 106730,
#  'saying': 168826,
#  'cut': 47716,
#  'fantastic': 69713,
#  'prisoners': 153820,
#  'famous': 69485,
#  'george': 80678,
#  'clooney': 39136,
#  'roll': 165295,
#  'man': 119044,
#  'constant': 42929,
#  'sorrow': 181551,
#  'recommand': 159861,
#  'everybody': 66143,
#  'greetings': 84725,
#  'bart': 19692,
#  'kind': 107815,
#  'drawn': 58159,
#  'erotic': 64946,
#  'amateurish': 10568,
#  'unbelievable': 204262,
#  'bits': 23939,
#  'sort': 181578,
#  'school': 169892,
#  'project': 154559,
#  'rosanna': 165785,
#  'arquette': 14776,
#  'thinking': 195834,
#  'stock': 185709,
#  'bizarre': 24006,
#  'supposed': 189550,
#  'midwest': 124696,
#  'town': 200118,
#  'involved': 101254,
#  'lessons': 112623,
#  'learned': 111695,
#  'insights': 99782,
#  'stilted': 185555,
#  'quite': 157248,
#  'ridiculous': 163829,
#  'lots': 116096,
#  'skin': 178416,
#  'intrigues': 100977,
#  'videotaped': 209236,
#  'nonsensewhat': 135652,
#  'bisexual': 23836,
#  'relationship': 161014,
#  'nowhere': 136805,
#  'heterosexual': 91123,
#  'encounters': 62850,
#  'absurd': 5081,
#  'dance': 48418,
#  'stereotyped': 185254,
#  'pass': 144955,
#  'million': 125030,
#  'miles': 124881,
#  'wasted': 211901,
#  'could': 44646,
#  'spent': 182700,
#  'starving': 184704,
#  'aids': 8490,
#  'africa': 7568,
#  'simply': 177485,
#  'remade': 161316,
#  'fails': 68978,
#  'capture': 32248,
#  'flavor': 74201,
#  'terror': 193774,
#  '1963': 1487,
#  'title': 198290,
#  'liam': 113009,
#  'neeson': 133163,
#  'excellent': 66669,
#  'always': 10451,
#  'holds': 92956,
#  'exception': 66732,
#  'owen': 143086,
#  'wilson': 215680,
#  'feel': 70978,
#  'character': 35192,
#  'luke': 117018,
#  'major': 118543,
#  'fault': 70519,
#  'version': 208719,
#  'strayed': 186733,
#  'shirley': 175476,
#  'jackson': 103238,
#  'attempts': 16238,
#  'grandiose': 84107,
#  'thrill': 196770,
#  'earlier': 60139,
#  'trade': 200349,
#  'snazzier': 179882,
#  'special': 182404,
#  'effects': 61055,
#  'enjoy': 63626,
#  'friction': 77292,
#  'older': 139082,
#  'top': 199429,
#  'horrible': 93975,
#  'wasnt': 211827,
#  'continuous': 43287,
#  'minute': 125651,
#  'fight': 71889,
#  'chance': 34863,
#  'development': 52601,
#  'busy': 30348,
#  'running': 166674,
#  'sword': 190690,
#  'emotional': 62550,
#  'attachment': 16167,
#  'except': 66726,
#  'machine': 117656,
#  'wanted': 211300,
#  'destroy': 52301,
#  'blatantly': 24458,
#  'stolen': 185773,
#  'lotr': 116092,
#  'wars': 211640,
#  'matrix': 121219,
#  'examplesthe': 66599,
#  'ghost': 81079,
#  'final': 73106,
#  'yoda': 219841,
#  'obee': 137482,
#  'vader': 207647,
#  'spider': 182755,
#  'beginning': 21293,
#  'frodo': 77611,
#  'attacked': 16176,
#  'return': 162945,
#  'kings': 107931,
#  'elijah': 61929,
#  'wood': 216966,
#  'victim': 209034,
#  'waitit': 210906,
#  'hypnotizes': 96141,
#  'stings': 185588,
#  'wraps': 218142,
#  'upuh': 207052,
#  'helloand': 90058,
#  'vs': 210599,
#  'humans': 95383,
#  'matrixor': 121231,
#  'terminatorthere': 193597,
#  'examples': 66587,
#  'someone': 180898,
#  'tell': 193169,
#  'nazis': 132772,
#  'juvenile': 105828,
#  'line': 114053,
#  'rushed': 166759,
#  'conclusion': 42091,
#  'childrens': 36697,
#  'adult': 7069,
#  'either': 61509,
#  'disappointment': 54658,
#  'save': 168660,
#  'remember': 161435,
#  'filmit': 72443,
#  'cinema': 37712,
#  'dark': 48763,
#  'places': 149111,
#  'nervous': 133535,
#  '7475': 3895,
#  'dad': 48057,
#  ...}

# %%
tf[0].toarray()
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])
